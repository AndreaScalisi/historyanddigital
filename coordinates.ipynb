# %%
import pandas as pd
import re
from collections import Counter
import spacy
from spacy.tokenizer import Tokenizer
from geopy.geocoders import Nominatim
from tqdm.autonotebook import tqdm
import time
import os
# Out:
# //anaconda3/lib/python3.7/site-packages/tqdm/autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
path = os.path.join('.', 'data', 'locations.csv')
locations = pd.read_csv(path)
locations.columns = ["chronoscope", "place"]
locations = locations.set_index("place")
locations.head(5)
# Out:
#                                                           chronoscope
# place
# National Museum of American History, Behring Ce...  chronoscope_13482
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# National Museum of American History, Behring Ce...  chronoscope_13184

# %%
path = os.path.join('.', 'data', 'coordinates.csv')
coordinates = pd.read_csv(path)
coordinates = coordinates.reset_index().drop("Unnamed: 2", axis=1)
coordinates.columns = ["place", "latitude", "longitude"]
coordinates.head(5)
# Out:
#                        place           latitude           longitude
# 0                 "Chicago"           "49.33725          11.42854"
# 1                  "Munich"            "48.1372           11.5755"
# 2               "Neuchatel"    "46.990277777778   6.9305555555556"
# 3   "University of Chicago"    "41.789722222222  -87.599722222222"
# 4              "Washington"             "38.895  -77.036666666667"

# %%
def clean(df): 
    df["place"] = df["place"].apply(lambda x: x.replace('"', ''))
    df["place"] = df["place"].apply(lambda x: x[1:-1])
    df["latitude"] = df["latitude"].apply(lambda x: float(x.replace('"', '')))
    df["longitude"] = df["longitude"].apply(lambda x: float(x.replace('"', '')))

# %%
clean(coordinates)
coordinates = coordinates.set_index("place")
coordinates.head(5)
# Out:
#                         latitude  longitude
# place
# Chicago                49.337250  11.428540
# Munich                 48.137200  11.575500
# Neuchatel              46.990278   6.930556
# University of Chicago  41.789722 -87.599722
# Washington             38.895000 -77.036667

# %%
def get_coord(places, coordinates):
    completed = places.copy()
    geolocator = Nominatim(user_agent="Hipp")
    nb_failed = 0
    notfound = []
    coord = None
    completed["latitude"] = 0.0
    completed["longitude"] = 0.0
    all_places = coordinates.index.tolist()
    wiki_coord = 0
    geopy_coord = 0
    
    for i in tqdm(range(len(places))):
        place = completed.index[i]
        if place in all_places:
            completed["latitude"][i] = coordinates.loc[place].latitude
            completed["longitude"][i] = coordinates.loc[place].longitude
            wiki_coord += 1
        else:
            try:
                coord = geolocator.geocode(place)
            except: 
                try:
                    coord = geolocator.geocode(place)
                except:
                    print("Failed")
                    nb_failed +=1
            
            if(coord):
                completed["latitude"][i] = coord.latitude
                completed["longitude"][i] = coord.longitude
                geopy_coord += 1
            else: 
                notfound.append(place)
                
    print("Failed " + str(nb_failed) + " requests.")
    print("Missed " + str(len(notfound))+ " places.")
    print(str(wiki_coord)+ " coordinates were already here, found "+ str(geopy_coord) + " more.")
    
    return (completed, notfound)

# %%
(completed, notfound) = get_coord(locations, coordinates)
completed
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Failed 0 requests.
# Missed 8 places.
# 3 coordinates were already here, found 13 more.
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_13482
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# National Museum of American History, Behring Ce...  chronoscope_13184
# Musée Histoire des Sciences, Genève                 chronoscope_13548
# University of Toronto Scientific Instruments Co...  chronoscope_13919
# University of Toronto Scientific Instruments Co...  chronoscope_14453
# National Museum of American History, Behring Ce...  chronoscope_14480
# KU Leuven - Faculty of Psychology and Education...  chronoscope_15057
# Musée de Bretagne et Ecomusée du pays de Rennes     chronoscope_16404
# University of Nebraska-Lincoln                      chronoscope_16897
# Université de Strasbourg                            chronoscope_17157
# Science museum, London                              chronoscope_20244
# Deutsches Museum                                    chronoscope_20260
# Darthmouth University                               chronoscope_20658
# The Barnard College Psychology Department           chronoscope_20659
# Dipartimento di Scienze Fisiche e Astronomiche,...   chronoscope_2505
# Cremona                                             chronoscope_25347
# Université de Strasbourg                             chronoscope_3716
# Rijksmuseum boerhaave                                chronoscope_5370
# Yale Peabody Museum of Natural History               chronoscope_7001
# Humboldt-universität zu berlin                       chronoscope_8319
# Musée Histoire des Sciences, Genève                  chronoscope_9258
#
#                                                      latitude  longitude
# place
# National Museum of American History, Behring Ce...   0.000000   0.000000
# National Museum of American History, Behring Ce...   0.000000   0.000000
# UNIL Lausanne                                       46.522570   6.580950
# Science museum, London                              51.497386  -0.174657
# National Museum of American History, Behring Ce...   0.000000   0.000000
# Musée Histoire des Sciences, Genève                  0.000000   0.000000
# University of Toronto Scientific Instruments Co...  43.662917 -79.395746
# University of Toronto Scientific Instruments Co...  43.662917 -79.395746
# National Museum of American History, Behring Ce...   0.000000   0.000000
# KU Leuven - Faculty of Psychology and Education...   0.000000   0.000000
# Musée de Bretagne et Ecomusée du pays de Rennes     48.077723  -1.666354
# University of Nebraska-Lincoln                      40.817500 -96.701389
# Université de Strasbourg                            48.578504   7.763608
# Science museum, London                              51.497386  -0.174657
# Deutsches Museum                                    48.130039  11.582888
# Darthmouth University                               44.968896 -93.261855
# The Barnard College Psychology Department            0.000000   0.000000
# Dipartimento di Scienze Fisiche e Astronomiche,...  38.110238  13.373410
# Cremona                                             45.220864  10.037038
# Université de Strasbourg                            48.578504   7.763608
# Rijksmuseum boerhaave                               52.161534   4.488904
# Yale Peabody Museum of Natural History              41.316050 -72.921132
# Humboldt-universität zu berlin                      52.518757  13.393560
# Musée Histoire des Sciences, Genève                  0.000000   0.000000

# %%
missing_places = pd.DataFrame({"place": notfound}).drop_duplicates()["place"].tolist()
missing_places
# Out:
# ['National Museum of American History, Behring Center',
#  'Musée Histoire des Sciences, Genève',
#  'KU Leuven - Faculty of Psychology and Educational Sciences',
#  'The Barnard College Psychology Department']

# %%
renamed_places = pd.DataFrame({"place": ["Behring Center", "Genève", "KU Leuven", "Barnard College"]
                               , "latitude": 0, "longitude": 0})
renamed_places = renamed_places.reset_index().drop("index", axis=1).set_index("place")
renamed_places
# Out:
#                  latitude  longitude
# place
# Behring Center          0          0
# Genève                  0          0
# KU Leuven               0          0
# Barnard College         0          0

# %%
(last_places, _) = get_coord(renamed_places, coordinates)
last_places
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# Failed 0 requests.
# Missed 0 places.
# 0 coordinates were already here, found 4 more.
#                   latitude  longitude
# place
# Behring Center   52.377850   9.737548
# Genève           46.201756   6.146601
# KU Leuven        50.873931   4.708316
# Barnard College  40.809705 -73.963389

# %%
final = completed.copy()

for i in tqdm(range(len(final))):
        place = final.index[i]
        for j in range(len(missing_places)):
            if place == missing_places[j]:
                final["latitude"][i] = last_places.loc[last_places.index[j]].latitude
                final["longitude"][i] = last_places.loc[last_places.index[j]].longitude

final
# Out:
# HBox(children=(IntProgress(value=0, max=24), HTML(value='')))
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_13482
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# National Museum of American History, Behring Ce...  chronoscope_13184
# Musée Histoire des Sciences, Genève                 chronoscope_13548
# University of Toronto Scientific Instruments Co...  chronoscope_13919
# University of Toronto Scientific Instruments Co...  chronoscope_14453
# National Museum of American History, Behring Ce...  chronoscope_14480
# KU Leuven - Faculty of Psychology and Education...  chronoscope_15057
# Musée de Bretagne et Ecomusée du pays de Rennes     chronoscope_16404
# University of Nebraska-Lincoln                      chronoscope_16897
# Université de Strasbourg                            chronoscope_17157
# Science museum, London                              chronoscope_20244
# Deutsches Museum                                    chronoscope_20260
# Darthmouth University                               chronoscope_20658
# The Barnard College Psychology Department           chronoscope_20659
# Dipartimento di Scienze Fisiche e Astronomiche,...   chronoscope_2505
# Cremona                                             chronoscope_25347
# Université de Strasbourg                             chronoscope_3716
# Rijksmuseum boerhaave                                chronoscope_5370
# Yale Peabody Museum of Natural History               chronoscope_7001
# Humboldt-universität zu berlin                       chronoscope_8319
# Musée Histoire des Sciences, Genève                  chronoscope_9258
#
#                                                      latitude  longitude
# place
# National Museum of American History, Behring Ce...  52.377850   9.737548
# National Museum of American History, Behring Ce...  52.377850   9.737548
# UNIL Lausanne                                       46.522570   6.580950
# Science museum, London                              51.497386  -0.174657
# National Museum of American History, Behring Ce...  52.377850   9.737548
# Musée Histoire des Sciences, Genève                 46.201756   6.146601
# University of Toronto Scientific Instruments Co...  43.662917 -79.395746
# University of Toronto Scientific Instruments Co...  43.662917 -79.395746
# National Museum of American History, Behring Ce...  52.377850   9.737548
# KU Leuven - Faculty of Psychology and Education...  50.873931   4.708316
# Musée de Bretagne et Ecomusée du pays de Rennes     48.077723  -1.666354
# University of Nebraska-Lincoln                      40.817500 -96.701389
# Université de Strasbourg                            48.578504   7.763608
# Science museum, London                              51.497386  -0.174657
# Deutsches Museum                                    48.130039  11.582888
# Darthmouth University                               44.968896 -93.261855
# The Barnard College Psychology Department           40.809705 -73.963389
# Dipartimento di Scienze Fisiche e Astronomiche,...  38.110238  13.373410
# Cremona                                             45.220864  10.037038
# Université de Strasbourg                            48.578504   7.763608
# Rijksmuseum boerhaave                               52.161534   4.488904
# Yale Peabody Museum of Natural History              41.316050 -72.921132
# Humboldt-universität zu berlin                      52.518757  13.393560
# Musée Histoire des Sciences, Genève                 46.201756   6.146601

# %%
path = os.path.join(".", "data", "exported.csv")
final.to_csv(path, index= True)
