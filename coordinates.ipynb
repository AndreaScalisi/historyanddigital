# %%
import pandas as pd
import re
from collections import Counter
import spacy
from spacy.tokenizer import Tokenizer
from geopy.geocoders import Nominatim
from tqdm.autonotebook import tqdm
import time
import os

# %%
path = os.path.join('.', 'data', 'locations.csv')
locations = pd.read_csv(path)
locations.columns = ["chronoscope", "place"]
locations = locations.set_index("place")
locations.head(5)
# Out:
#                                                           chronoscope
# place
# National Museum of American History, Behring Ce...  chronoscope_13482
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# National Museum of American History, Behring Ce...  chronoscope_13184

# %%
path = os.path.join('.', 'data', 'coordinates.csv')
coordinates = pd.read_csv(path)
coordinates = coordinates.reset_index().drop("Unnamed: 2", axis=1)
coordinates.columns = ["place", "latitude", "longitude"]
coordinates.head(5)
# Out:
#                        place           latitude           longitude
# 0                 "Chicago"           "49.33725          11.42854"
# 1                  "Munich"            "48.1372           11.5755"
# 2               "Neuchatel"    "46.990277777778   6.9305555555556"
# 3   "University of Chicago"    "41.789722222222  -87.599722222222"
# 4              "Washington"             "38.895  -77.036666666667"

# %%
def clean(df): 
    df["place"] = df["place"].apply(lambda x: x.replace('"', ''))
    df["place"] = df["place"].apply(lambda x: x[1:-1])
    df["latitude"] = df["latitude"].apply(lambda x: float(x.replace('"', '')))
    df["longitude"] = df["longitude"].apply(lambda x: float(x.replace('"', '')))

# %%
clean(coordinates)
coordinates = coordinates.set_index("place")
coordinates.head(5)
# Out:
#                         latitude  longitude
# place
# Chicago                49.337250  11.428540
# Munich                 48.137200  11.575500
# Neuchatel              46.990278   6.930556
# University of Chicago  41.789722 -87.599722
# Washington             38.895000 -77.036667

# %%
def get_coord(places, coordinates):
    completed = places.copy()
    geolocator = Nominatim(user_agent="Hipp")
    nb_failed = 0
    notfound = []
    coord = None
    completed["current_coordinates"] = ""
    all_places = coordinates.index.tolist()
    wiki_coord = 0
    geopy_coord = 0
    
    for i in tqdm(range(len(places))):
        place = completed.index[i]
        if place in all_places:
            completed["current_coordinates"][i] = str(coordinates.loc[place].latitude) + ", " + str(coordinates.loc[place].longitude)
            wiki_coord += 1
        else:
            try:
                coord = geolocator.geocode(place)
            except: 
                try:
                    coord = geolocator.geocode(place)
                except:
                    print("Failed")
                    nb_failed +=1
            
            if(coord):
                completed["current_coordinates"][i] = str(coord.latitude) + ", " + str(coord.longitude)
                geopy_coord += 1
            else: 
                notfound.append(place)
                
    print("Failed " + str(nb_failed) + " requests.")
    print("Missed " + str(len(notfound))+ " places.")
    print(str(wiki_coord)+ " coordinates were already here, found "+ str(geopy_coord) + " more.")
    
    return (completed, notfound)

# %%
path = os.path.join(".", "data", "production.csv")
production = pd.read_csv(path)
production.columns = ["chronoscope", "manufacter", "production_place", "place", "time_production"]
production = production.set_index("place")
production.head()
# Out:
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# Dipartimento di Scienze Fisiche e Astronomiche,...   chronoscope_2505
# Université de Strasbourg                             chronoscope_3716
#
#                                                           manufacter  \
# place
# National Museum of American History, Behring Ce...  Hipp_manufacture
# UNIL Lausanne                                       Hipp_manufacture
# Science museum, London                              Hipp_manufacture
# Dipartimento di Scienze Fisiche e Astronomiche,...  Hipp_manufacture
# Université de Strasbourg                            Hipp_manufacture
#
#                                                    production_place  \
# place
# National Museum of American History, Behring Ce...        Neuchatel
# UNIL Lausanne                                             Neuchatel
# Science museum, London                                    Neuchatel
# Dipartimento di Scienze Fisiche e Astronomiche,...        Neuchatel
# Université de Strasbourg                                  Neuchatel
#
#                                                    time_production
# place
# National Museum of American History, Behring Ce...       1875-1879
# UNIL Lausanne                                            1886-1887
# Science museum, London                                        1888
# Dipartimento di Scienze Fisiche e Astronomiche,...            1865
# Université de Strasbourg                                 1850-1899

# %%
(production_coord, notfound_prod) = get_coord(production, coordinates)
# Out:
# HBox(children=(IntProgress(value=0, max=18), HTML(value='')))
# Failed 0 requests.
# Missed 5 places.
# 2 coordinates were already here, found 11 more.

# %%
production_coord.head()
# Out:
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# Dipartimento di Scienze Fisiche e Astronomiche,...   chronoscope_2505
# Université de Strasbourg                             chronoscope_3716
#
#                                                           manufacter  \
# place
# National Museum of American History, Behring Ce...  Hipp_manufacture
# UNIL Lausanne                                       Hipp_manufacture
# Science museum, London                              Hipp_manufacture
# Dipartimento di Scienze Fisiche e Astronomiche,...  Hipp_manufacture
# Université de Strasbourg                            Hipp_manufacture
#
#                                                    production_place  \
# place
# National Museum of American History, Behring Ce...        Neuchatel
# UNIL Lausanne                                             Neuchatel
# Science museum, London                                    Neuchatel
# Dipartimento di Scienze Fisiche e Astronomiche,...        Neuchatel
# Université de Strasbourg                                  Neuchatel
#
#                                                    time_production  \
# place
# National Museum of American History, Behring Ce...       1875-1879
# UNIL Lausanne                                            1886-1887
# Science museum, London                                        1888
# Dipartimento di Scienze Fisiche e Astronomiche,...            1865
# Université de Strasbourg                                 1850-1899
#
#                                                               current_coordinates
# place
# National Museum of American History, Behring Ce...
# UNIL Lausanne                                        46.5225695, 6.58095049765429
# Science museum, London                              51.4973861, -0.17465652444465
# Dipartimento di Scienze Fisiche e Astronomiche,...  38.11023805, 13.3734100676556
# Université de Strasbourg                             48.5785039, 7.76360811797386

# %%
notfound_prod
# Out:
# ['National Museum of American History, Behring Center',
#  'Musée Histoire des Sciences, Genève',
#  'National Museum of American History, Behring Center',
#  'Musée Histoire des Sciences, Genève',
#  'National Museum of American History, Behring Center']

# %%
missing_places = pd.DataFrame({"place": notfound_prod}).drop_duplicates()["place"].tolist()
missing_places
# Out:
# ['National Museum of American History, Behring Center',
#  'Musée Histoire des Sciences, Genève']

# %%
renamed_places = pd.DataFrame({"place": ["Behring Center", "Genève"]
                               , "cuurent_coordinates": ""})
renamed_places = renamed_places.reset_index().drop("index", axis=1).set_index("place")
renamed_places
# Out:
#                cuurent_coordinates
# place
# Behring Center
# Genève

# %%
(last_places, _) = get_coord(renamed_places, coordinates)
last_places
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# Failed 0 requests.
# Missed 0 places.
# 0 coordinates were already here, found 2 more.
#                cuurent_coordinates            current_coordinates
# place
# Behring Center                      52.37785035, 9.73754758207386
# Genève                                      46.2017559, 6.1466014

# %%
final = production_coord.copy()

for i in tqdm(range(len(final))):
        place = final.index[i]
        for j in range(len(missing_places)):
            if place == missing_places[j]:
                final["current_coordinates"][i] = str(last_places.loc[last_places.index[j]].current_coordinates)

final
# Out:
# HBox(children=(IntProgress(value=0, max=18), HTML(value='')))
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# National Museum of American History, Behring Ce...            1905
# Université de Strasbourg                                      1898
# Deutsches Museum                                         1875-1899
# Darthmouth University                                         1900
# Cremona                                                       1877
#
#                                                               current_coordinates
# place
# National Museum of American History, Behring Ce...  52.37785035, 9.73754758207386
# UNIL Lausanne                                        46.5225695, 6.58095049765429
# Science museum, London                              51.4973861, -0.17465652444465
# Dipartimento di Scienze Fisiche e Astronomiche,...  38.11023805, 13.3734100676556
# Université de Strasbourg                             48.5785039, 7.76360811797386
# Rijksmuseum boerhaave                                       52.1615338, 4.4889042
# Yale Peabody Museum of Natural History              41.3160498, -72.9211317278171
# Humboldt-universität zu berlin                      52.51875685, 13.3935604936378
# Musée Histoire des Sciences, Genève                         46.2017559, 6.1466014
# National Museum of American History, Behring Ce...  52.37785035, 9.73754758207386
# Musée Histoire des Sciences, Genève                         46.2017559, 6.1466014
# University of Toronto Scientific Instruments Co...          43.662917, -79.395746
# University of Toronto Scientific Instruments Co...          43.662917, -79.395746
# National Museum of American History, Behring Ce...  52.37785035, 9.73754758207386
# Université de Strasbourg                             48.5785039, 7.76360811797386
# Deutsches Museum                                    48.13003865, 11.5828884885519
# Darthmouth University                               44.9688959, -93.2618548027095
# Cremona                                             45.22086405, 10.0370379796289

# %%
neuch_coord = "46.990278, 6.930556"
final["initial_coordinates"] = neuch_coord
final.head()
# Out:
#                                                           chronoscope  \
# place
# National Museum of American History, Behring Ce...  chronoscope_10107
# UNIL Lausanne                                       chronoscope_12692
# Science museum, London                              chronoscope_13074
# Dipartimento di Scienze Fisiche e Astronomiche,...   chronoscope_2505
# Université de Strasbourg                             chronoscope_3716
#
#                                                           manufacter  \
# place
# National Museum of American History, Behring Ce...  Hipp_manufacture
# UNIL Lausanne                                       Hipp_manufacture
# Science museum, London                              Hipp_manufacture
# Dipartimento di Scienze Fisiche e Astronomiche,...  Hipp_manufacture
# Université de Strasbourg                            Hipp_manufacture
#
#                                                    production_place  \
# place
# National Museum of American History, Behring Ce...        Neuchatel
# UNIL Lausanne                                             Neuchatel
# Science museum, London                                    Neuchatel
# Dipartimento di Scienze Fisiche e Astronomiche,...        Neuchatel
# Université de Strasbourg                                  Neuchatel
#
#                                                    time_production  \
# place
# National Museum of American History, Behring Ce...       1875-1879
# UNIL Lausanne                                            1886-1887
# Science museum, London                                        1888
# Dipartimento di Scienze Fisiche e Astronomiche,...            1865
# Université de Strasbourg                                 1850-1899
#
#                                                               current_coordinates  \
# place
# National Museum of American History, Behring Ce...  52.37785035, 9.73754758207386
# UNIL Lausanne                                        46.5225695, 6.58095049765429
# Science museum, London                              51.4973861, -0.17465652444465
# Dipartimento di Scienze Fisiche e Astronomiche,...  38.11023805, 13.3734100676556
# Université de Strasbourg                             48.5785039, 7.76360811797386
#
#                                                     initial_coordinates
# place
# National Museum of American History, Behring Ce...  46.990278, 6.930556
# UNIL Lausanne                                       46.990278, 6.930556
# Science museum, London                              46.990278, 6.930556
# Dipartimento di Scienze Fisiche e Astronomiche,...  46.990278, 6.930556
# Université de Strasbourg                            46.990278, 6.930556

# %%
path = os.path.join(".", "data", "production_coordinates.csv")
final.to_csv(path, index= True)
